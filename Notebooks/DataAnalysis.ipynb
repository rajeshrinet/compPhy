# %% [markdown]
# # Statistical inference
#
# * statistics
# * inference
# * population
# * samples
# * estimate
#
# # Probability
# * coin toss statistics
#
# # Plotting in python
# * histograms
# * maps
# * basic analysis
#
# We will do these three things together and depeding on interest, we will decide on the proportion!

# %%
from IPython.display import HTML
HTML('<iframe src=http://imgs.xkcd.com/comics/convincing.png width=740 height=310></iframe>')
# Out:
# <iframe src=http://imgs.xkcd.com/comics/convincing.png width=740 height=310></iframe>

# %% [markdown]
# ### Statistical inference
# Statistical inference means making use of available informations for drawing conclusions (inferences) about the population from which the sample was taken
# # Population
# A population is the entire group we are interested in and wish to describe or draw conclusions about it.
#
# ### Samples
#
# To know about a population we take recourse to sampling.
#
# A sample is a group of the larger group (the population). We draw valid conclusions about the larger group by studying the sample.
#
# * Samples are group of observation drawn from a bigger population.
# * All this effort is to know about a bigger population based on sample.

# %%
from IPython.display import HTML
HTML('<iframe src=http://www.nazlinur.com/wp-content/uploads/2013/01/1927-Solvay-Conference1-1024x698.jpg width=1030 height=750></iframe>')
# Out:
# <iframe src=http://www.nazlinur.com/wp-content/uploads/2013/01/1927-Solvay-Conference1-1024x698.jpg width=1030 height=750></iframe>

# %% [markdown]
# ## Examples
# ### Voting
# Lets say that there are 2 parties XP and YP contensting election in Chennai!
#
# Supppose we want to know what is the fraction of votes polled for XP.
#
# Now u can not ask just everbody!

# %% [markdown]
#    We will discuss data analysis
#
#    * Coin toss statistics
#    * Basics of probability and its interpretation
#    * Plotting and very basic programming in python
#    * Some examples

# %% [markdown]
# ### Coin toss statistics

# %% [markdown]
# ## Plotting in python

# %% [markdown]
# ## Program- but why?
# * its challenging and fun
# * creativity, reasoning, problem solving skill
# ## Python?
# * easy to learn and at same time powerful
# * multipurpose
# * beautiful design

# %%
import antigravity

# %%
print 'Hello World!'
# Out:
# Hello World!

# %%
#Python as calculator
4 + 9
# Out:
# 13

# %%
a = 'python'
b= ' is fun!'
print a+b
# Out:
# python is fun!

# %%
import pandas as pd

s = pd.Series({'Mango':44, 'Banana':36, 'Apple':20, 'Chickoo':4, 'Guava':1, 'Lichi':14})
s.plot(kind='bar', rot=0)

# %%
import turtle
t = turtle.Pen()
t.forward(20)
t.left(20)
t.forward(20)
t.left(20)
t.forward(20)

# %% [markdown]
# ### Basemaps

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
 
 
map = Basemap(projection='ortho', lat_0=22, lon_0=77,
              resolution='l', area_thresh=10)

# Draw just the coast lines
map.drawcoastlines()
 
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
 
 
map = Basemap(projection='ortho', lat_0=22, lon_0=77,
              resolution='l', area_thresh=1000.0)

# Add continents
map.drawcoastlines(linewidth=1.2)
map.drawcountries(linewidth=1.2)
#map.fillcontinents(color='coral',lake_color='aqua')

 
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

 
map = Basemap(projection='ortho', lat_0=22, lon_0=77,
              resolution='l', area_thresh=1000.0)


map.drawcoastlines(linewidth=.2)
map.drawcountries(linewidth=1.2)
map.fillcontinents(color='coral',lake_color='aqua')

map.drawmapboundary(fill_color='aqua')
date = datetime.utcnow()

CS=map.nightshade(date)
 
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
 
 
map = Basemap(projection='ortho', lat_0=22, lon_0=77,
              resolution='l', area_thresh=1000.0)

map.drawcoastlines(linewidth=.2)
map.drawcountries(linewidth=.2)
map.fillcontinents(color='coral',lake_color='aqua')

map.drawmapboundary(fill_color='aqua')

# Draw meridians
map.drawmeridians(np.arange(0, 360, 30))
map.drawparallels(np.arange(-90, 90, 30))
 
plt.show()

# %%
import numpy as np
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from datetime import datetime

# miller projection
map = Basemap(projection='mill',lon_0=0)

# plot coastlines, draw label meridians and parallels.
map.drawcoastlines()
map.drawparallels(np.arange(-90,90,30),labels=[1,0,0,0])
map.drawmeridians(np.arange(map.lonmin,map.lonmax+30,60),labels=[0,0,0,1])
# fill continents 'coral' (with zorder=0), color wet areas 'aqua'
map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral',lake_color='aqua')
# shade the night areas, with alpha transparency so the
# map shows through. Use current time in UTC.
date = datetime.utcnow()
CS=map.nightshade(date)
plt.title('Day/Night Map for %s (UTC)' % date.strftime("%d %b %Y %H:%M:%S"))
plt.show()

# %%
import pytz
import datetime as dt
now = dt.datetime.now()
print(now)
# Out:
# 2014-04-19 14:39:14.125875
