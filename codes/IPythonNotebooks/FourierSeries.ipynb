# %% [markdown]
# ## Fourier methods
#
# Fourier transform (FT) for a well-behaved functions $f$ is defined as:
#
# $$f(k) = \int e^{ikx} f(x) ~dx$$
#
# The inverse FT is then
#
# $$f(x) = \frac{1}{2\pi} \int e^{ikx} f(k) ~dk$$

# %% [markdown]
# ## Discrete fourier tranforms (DFTs)
#
#
# If the function is periodic in real space, $f(x+L) = f(x)$, as well discrete with the spacing $h$, then the Fourier space is discrete with spacing $\frac{2\pi}{L}$.
#
# $$f(x) = \sum e^{ikx} f(k) ~dk~~~~~~      \text{where } k = \Bigg[ -\frac{\pi}{h}, \frac{\pi}{h}\Bigg];~~ \text{with interval} \frac{2\pi}{L} $$
#
#
# This is very much in line with crystallography with $ [ -\frac{\pi}{h}, \frac{\pi}{h} ]$ being the Brillouin zone. So we see that there is a concept of the maximum wavenumber $ k_{max}=\frac{\pi}{h} $, we will get back to this later in the notes. Usually in computations we need to find FT of discrete function rather than of a well defined analytic function. Since the real space is periodic and discrete, the Fourier space is both bounded and discrete. Also, the Fourier space is continous if the real space is unbounded. If the function is defined at $N$ points in real space and one wants to calculate the function at $N$ points in Fourier space, then DFT is defined as
#
# $$f_k = \sum_{n=0}^{N-1} f_n ~ e^{i~2\pi~k~n~/~N}$$
#
# while the inverse of this is
#
# $$f_n = \sum_{n=0}^{N-1} f_k ~ e^{i~2\pi~k~n~/~N}$$
#
# To calculate each $f_n$ one needs $N$ computations and it has to be done $N$ times, i.e, the algorithm is simply $\mathcal{O}(N^2)$. This can be implemented numerically as a matrix multiplication, $f_k = M\cdot f_n$, where $M$ is a $N\times N$ matrix.

# %% [markdown]
# ## Fast fourier tranforms (FFTs)
#
# FFTs improves on DFTs by exploiting their symmetries.
#
# $$ \begin{align}
# f_k &= \sum_{n=0}^{N-1} f_n  e^{-i~\frac{2\pi~k~n}{N}} \\
# &= \sum_{n=0}^{N/2-1} f_{2n} e^{-i~\frac{2\pi~k~2n}{N}} &+ \sum_{n=0}^{N/2-1} f_{2n + 1} e^{-i~\frac{2\pi~k~(n+1)}{N}}\\
# &= \sum_{n=0}^{N/2 - 1} f_{2n} e^{-i~\frac{2\pi k~n}{N/2}} &+ e^{-i\frac{2\pi}{N}} \sum_{n=0}^{N/2 - 1} f_{2n + 1} e^{-i~\frac{2\pi~k~n~}{N/2}}\\
# &=\vdots &\vdots
# \end{align}$$
#
# Because of the tree structure the complexity of the problem becomes $\mathcal{O}(N \ln N)$ which becomes a major advantage over the $\mathcal{O}(N^2)$ algorithm. Below we will look at a simple implementation of FFT

# %%
from __future__ import division
import numpy as np

# %%
def testFFT(x):
    ''' FFT in 1d  '''
    N = x.shape[0]
    if N % 2 > 0:
        raise Exception('x must have even size')
    elif N <= 16: 
        ''' this is the naive implementation using matrix multiplication'''
        n = np.arange(N)
        k = n.reshape((N, 1))
        M = np.exp(-2j * np.pi * k * n / N)
        return np.dot(M, x)
    else:
        M1 = testFFT(x[::2])
        M2 = testFFT(x[1::2])
        fac = np.exp(-2j * np.pi * np.arange(N) / N)
        return np.concatenate([M1+fac[:N/2] * M2, M1+fac[N/2:]*M2])

# %%
x = np.random.random(1024)
np.allclose(np.fft.fftn(x), testFFT(x))
# Out:
# True

# %%
# TRANSLATION by e^{ikr}!
L, N = 64, 128       
ll =  linspace(0, L, N)    
x, y = meshgrid(ll, ll)

# Fourier grid.
kx = 2 * np.pi / L * np.concatenate((np.arange(0, N/2+1,1),np.arange(-N/2+1, 0, 1)))  # k = (2\pi)/L
ky = 2 * np.pi / L * np.concatenate((np.arange(0, N/2+1,1),np.arange(-N/2+1, 0, 1)))
kx, ky = np.meshgrid(kx, ky) 

def plotFirst(x, y, sig, n_):
    sp =  f.add_subplot(1, 3, n_ )
    pcolormesh(x, y, sig, cmap=plt.cm.gist_heat_r)
    axis('off');
    
f = plt.figure(figsize=(20, 5), dpi=80);  
rr = sqrt( (x - L/2)*(x - L/2) + (y - L/2)*(y - L/2) )
sig = np.fft.fftn(exp(-0.1*rr))

xx = ([-L/4, L/2, -L/2,])
yy = ([-L/8, -L/9, L/2])
for i in range(3):
    kdotr = kx*xx[i] + ky *yy[i]
    sig = sig*exp(-1j*kdotr)
    plotFirst(x, y, np.fft.ifftn(sig), i+1)

# %% [markdown]
# ## More examples
# ### Sampling: Aliasing error
#
# We saw that because of the smallest length scale, $h$, in the real space there is a corresponding largest wave-vector, $k_{max}$ in the Fourier space. There is this error becuase of this $k_{max}$ and a signal which has $k>k_{max}$ can not be distinguished.
# In the example below we see that if the real space has 10 points that one can not distinguish between $sin(2\pi x/L)$ and $sin(34 \pi x/L)$. In general, $sin(k_1 x)$ and $sin(k_2 x)$ can not be distinguished if $k_1 -k_2$ is a multiple of $\frac{2\pi}{h}$. This is a manifestation of the gem called the sampling theorem which is defined, as on wikipedia:
#
# If a function x(t) contains no frequencies higher than B hertz, it is completely determined by giving its ordinates at a series of points spaced 1/(2B) seconds apart.

# %%
L, N = 1, 16
x = np.arange(0, L, L/512)
xx = np.arange(0, L, L/N)

def ff(k, x):
    return sin(k*x)

# %%
f = plt.figure(figsize=(17, 6), dpi=80);  

plot(x, ff(x, 2*pi), color="#A60628", linewidth=2);
plot(x, ff(x, 34*pi), color="#348ABD", linewidth=2);
plot(xx, ff(xx, 2*pi), 'o', color="#020e3e", markersize=8)
xlabel('x', fontsize=15); ylabel('y(x)', fontsize=15);
title('Aliasing in sampling of $sin(2\pi x/L)$ and $sin(34 \pi x/L)$', fontsize=15);

# %% [markdown]
#  ### Differentiation
#
#  In this section we will use the in-built FFT modules of numpy and then perform differntiation. Differentiation in Fourier space is trivial, $\mathbf{\nabla}_{\alpha}$ gets reaplaces by $ik_{\alpha}$. Steps involved are
#
# * FFT the function to be differentiated.
# * multiply by suitable numbers of $ik$
# * IFFT on the resulting thing to get the differentiated function in real space.

# %%
from __future__ import division
def f1(kk, x):
    return cos(kk*x)

# %%
f = plt.figure(figsize=(10, 5), dpi=80);  

L, N = 1, 32
kk   = 2*pi/L
x = arange(0, N)*(L/N)     
k = np.concatenate(( np.arange(0, N/2+1,1), np.arange(-N/2+1, 0, 1) ))*(2*pi/L)

fk = np.fft.fft(f1(kk, x))         
f1_kk = -k*k*fk               
f1_xx = np.fft.ifft(f1_kk)

 
plot(x, -f1(kk, x)*kk*kk, color="#348ABD", label = 'analytical', linewidth=2)          
plot(x, f1_xx, 'o', color="#A60628", label = 'numerical', markersize=6)     
legend(loc = 'best')
xlabel('x', fontsize=15)
title('derivatives using FFT', fontsize=15)
xlim([0, max(x)]);

# %% [markdown]
# Since we know that the function in real, there are additional symmetry properties. Wavenumbers corresponding to $j$ and $N-j$ are same and hence we only need to consider wavenumber till N/2!

# %%
# since we knwo that functions are real then we could save some time and memory by using real FFTs.
f = plt.figure(figsize=(10, 5), dpi=80);  

L, N = 1, 64     
x = np.arange(0, L, L/N)  
kk   = 4*pi/L
k =  arange(0, N/2 + 1)*(2*pi/L)

# k[2] = 0 # all the pattern is dead at a particular k mode which coooresponds to the signal!!

fk = np.fft.rfft(f1(kk, x))         
fk = -k*k*fk               
fx = np.fft.irfft(fk)

plot(x, -kk*kk*f1(kk, x), color="#348ABD", label = 'analytical', linewidth=2)          
plot(x, fx, 'o', color="#A60628", label = 'numerical')     
legend(loc = 'best')
xlabel('x', fontsize=15)
title('derivatives using FFT', fontsize=15)
xlim([0, max(x)]);
